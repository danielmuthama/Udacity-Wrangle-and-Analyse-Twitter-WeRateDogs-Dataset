# %% [markdown]
# # GATHERING

# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Using cached tweepy-4.10.1-py3-none-any.whl (94 kB)
# Collecting oauthlib<4,>=3.2.0
#   Using cached oauthlib-3.2.1-py3-none-any.whl (151 kB)
# Collecting requests<3,>=2.27.0
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting requests-oauthlib<2,>=1.2.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2022.9.24-py3-none-any.whl (161 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pnm\appdata\local\programs\python\python37\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.4)
# Installing collected packages: urllib3, oauthlib, charset-normalizer, certifi, requests, requests-oauthlib, tweepy
# Successfully installed certifi-2022.9.24 charset-normalizer-2.1.1 oauthlib-3.2.1 requests-2.28.1 requests-oauthlib-1.3.1 tweepy-4.10.1 urllib3-1.26.12
# Note: you may need to restart the kernel to use updated packages.

# %%
#inportation of all libaries
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer
from IPython.display import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11316\1799623632.py in <module>
#       4 import pandas as pd
#       5 import numpy as np
# ----> 6 import matplotlib.pyplot as plt
#       7 import seaborn as sns
#       8 import requests
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ### Enhanced Twitter Archive

# %%
#import of the enhanced twitter archieve dataset
twitter_archive_enhanced=pd.read_csv(r'C:\Users\Samuel\Desktop\ALX\project 2\twitter-archive-enhanced.csv')

# %%
twitter_archive_enhanced
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 17 columns]

# %% [markdown]
# ### Image Predictions Datset

# %%
#import of the image prediction dataset by use of the request get method
url='https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response=requests.get(url)

# %%
#creatation of a folder and we checck if it is already existing
folder_name = 'image_prediction'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
with open(os.path.join(folder_name,url.split('/')[-1]),mode='wb') as file:
        file.write(response.content)

# %%
#confirmation of the file if it is saved
os.listdir(folder_name)
# Out:
# ['image-predictions.tsv']

# %%
#read the file using pandas 
image_prediction=pd.read_csv('image_prediction\image-predictions.tsv',sep='\t')

# %%
#view the image prediction dataset
image_prediction
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# 0           1  Welsh_springer_spaniel  0.465074    True              collie
# 1           1                 redbone  0.506826    True  miniature_pinscher
# 2           1         German_shepherd  0.596461    True            malinois
# 3           1     Rhodesian_ridgeback  0.408143    True             redbone
# 4           1      miniature_pinscher  0.560311    True          Rottweiler
# ...       ...                     ...       ...     ...                 ...
# 2070        2                  basset  0.555712    True    English_springer
# 2071        1             paper_towel  0.170278   False  Labrador_retriever
# 2072        1               Chihuahua  0.716012    True            malamute
# 2073        1               Chihuahua  0.323581    True            Pekinese
# 2074        1                  orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0     0.156665    True            Shetland_sheepdog  0.061428    True
# 1     0.074192    True          Rhodesian_ridgeback  0.072010    True
# 2     0.138584    True                   bloodhound  0.116197    True
# 3     0.360687    True           miniature_pinscher  0.222752    True
# 4     0.243682    True                     Doberman  0.154629    True
# ...        ...     ...                          ...       ...     ...
# 2070  0.225770    True  German_short-haired_pointer  0.175219    True
# 2071  0.168086    True                      spatula  0.040836   False
# 2072  0.078253    True                       kelpie  0.031379    True
# 2073  0.090647    True                     papillon  0.068957    True
# 2074  0.085851   False                       banana  0.076110   False
#
# [2075 rows x 12 columns]

# %%
image_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# ## Additional data from the Twitter API

# %%
#The above is the code to run using a develper account.
#consumer_key = 'My KEY'
#consumer_secret = 'My SECRET'
#access_token = 'My TOKEN'
#access_secret = 'My Access SECRET'
#
#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_secret)
#
#api = tweepy.API(auth)

# %%
#gathering of the twitter api and we get only the tweet ID, retweet count and favourite count valaues only.
#Considering the unavailiabity of my develpoer account i was given the data handy for the sake of time constarint. 
#which made me to use the below code to use the data that was gotten by a different developer account 

listing=[]
count=0
filing='tweet-json.txt'
with open(filing, encoding='utf-8') as file:
    for the_file in file:
        count +=1
        json_file=file.readline()
        mydata=(json.loads(the_file))
        tweet_id=mydata['id']
        retweet_count=mydata['retweet_count']
        favorite_count=mydata['favorite_count']
        listing.append({'tweet_id':tweet_id,'retweet_count':retweet_count,'favorite_count':favorite_count})
        
        twitter_api=pd.DataFrame(listing,columns=['tweet_id','retweet_count','favorite_count'])

# %% [markdown]
# # ACCESSING

# %% [markdown]
# #### Twitter Archive Enhanced

# %%
#we view only the first five rows
twitter_archive_enhanced.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
#we randomly view 10 rows of the dataset
twitter_archive_enhanced.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2171  669328503091937280                    NaN                  NaN
# 1937  673919437611909120                    NaN                  NaN
# 1004  747816857231626240                    NaN                  NaN
# 1890  674767892831932416                    NaN                  NaN
# 1509  691459709405118465                    NaN                  NaN
# 2125  670361874861563904                    NaN                  NaN
# 1294  707995814724026368                    NaN                  NaN
# 1121  730924654643314689                    NaN                  NaN
# 1123  730427201120833536                    NaN                  NaN
# 1488  692919143163629568                    NaN                  NaN
#
#                       timestamp  \
# 2171  2015-11-25 01:35:25 +0000
# 1937  2015-12-07 17:38:09 +0000
# 1004  2016-06-28 15:40:07 +0000
# 1890  2015-12-10 01:49:36 +0000
# 1509  2016-01-25 03:16:56 +0000
# 2125  2015-11-27 22:01:40 +0000
# 1294  2016-03-10 18:25:30 +0000
# 1121  2016-05-13 00:56:32 +0000
# 1123  2016-05-11 15:59:50 +0000
# 1488  2016-01-29 03:56:12 +0000
#
#                                                  source  \
# 2171  <a href="http://twitter.com/download/iphone" r...
# 1937  <a href="http://twitter.com/download/iphone" r...
# 1004  <a href="http://twitter.com/download/iphone" r...
# 1890  <a href="http://twitter.com/download/iphone" r...
# 1509  <a href="http://twitter.com/download/iphone" r...
# 2125  <a href="http://twitter.com/download/iphone" r...
# 1294  <a href="http://twitter.com/download/iphone" r...
# 1121  <a href="http://twitter.com/download/iphone" r...
# 1123  <a href="http://twitter.com/download/iphone" r...
# 1488  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2171  This is Kirk. He just saw a bacon wrapped tenn...                  NaN
# 1937  This is Obie. He is on guard watching for evil...                  NaN
# 1004  Viewer discretion is advised. This is a terrib...                  NaN
# 1890  This pup was carefully tossed to make it look ...                  NaN
# 1509  Say hello to Leo. He's a Fallopian Puffalope. ...                  NaN
# 2125  This is a Rich Mahogany Seltzer named Cherokee...                  NaN
# 1294  This is Farfle. He lost his back legs during t...                  NaN
# 1121  We only rate dogs. Pls stop sending non-canine...                  NaN
# 1123  This is Crystal. She's flawless. Really wants ...                  NaN
# 1488  Please only send in dogs. Don't submit other t...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 2171                       NaN                        NaN
# 1937                       NaN                        NaN
# 1004                       NaN                        NaN
# 1890                       NaN                        NaN
# 1509                       NaN                        NaN
# 2125                       NaN                        NaN
# 1294                       NaN                        NaN
# 1121                       NaN                        NaN
# 1123                       NaN                        NaN
# 1488                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 2171  https://twitter.com/dog_rates/status/669328503...                12
# 1937  https://twitter.com/dog_rates/status/673919437...                11
# 1004  https://twitter.com/dog_rates/status/747816857...                 4
# 1890  https://twitter.com/dog_rates/status/674767892...                12
# 1509  https://twitter.com/dog_rates/status/691459709...                12
# 2125  https://twitter.com/dog_rates/status/670361874...                 9
# 1294  https://twitter.com/dog_rates/status/707995814...                12
# 1121  https://twitter.com/dog_rates/status/730924654...                 9
# 1123  https://twitter.com/dog_rates/status/730427201...                11
# 1488  https://twitter.com/dog_rates/status/692919143...                 9
#
#       rating_denominator          name doggo floofer  pupper puppo
# 2171                  10          Kirk  None    None    None  None
# 1937                  10          Obie  None    None  pupper  None
# 1004                  10             a  None    None    None  None
# 1890                  10          None  None    None    None  None
# 1509                  10           Leo  None    None    None  None
# 2125                  10             a  None    None    None  None
# 1294                  10        Farfle  None    None    None  None
# 1121                  10  unacceptable  None    None    None  None
# 1123                  10       Crystal  None    None    None  None
# 1488                  10          None  None    None    None  None

# %%
#we get the information of the dataset about the datatype,count and the total entries for the dataset
twitter_archive_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
#This help us understand the datset better by viewing the mean,standard deviation, maximumm etc 
twitter_archive_enhanced.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# 25%           7.186315e+17              4.196984e+09         10.000000
# 50%           7.804657e+17              4.196984e+09         11.000000
# 75%           8.203146e+17              4.196984e+09         12.000000
# max           8.874740e+17              7.874618e+17       1776.000000
#
#        rating_denominator
# count         2356.000000
# mean            10.455433
# std              6.745237
# min              0.000000
# 25%             10.000000
# 50%             10.000000
# 75%             10.000000
# max            170.000000

# %%
# we still attempt other method to checck for dduplicated in the tweet ID column
twitter_archive_enhanced.tweet_id.nunique()
# Out:
# 2356

# %%
#we check if for the retweet status column tthere exist empty values
twitter_archive_enhanced.retweeted_status_user_id.isna().value_counts()
# Out:
# True     2175
# False     181
# Name: retweeted_status_user_id, dtype: int64

# %%
# We get the sum of each columns having empty or null values
twitter_archive_enhanced.isna().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
# we view the twitter rating numerators to check if there are problems
twitter_archive_enhanced.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 2         9
# 1         9
# 75        2
# 15        2
# 420       2
# 0         2
# 80        1
# 144       1
# 17        1
# 26        1
# 20        1
# 121       1
# 143       1
# 44        1
# 60        1
# 45        1
# 50        1
# 99        1
# 204       1
# 1776      1
# 165       1
# 666       1
# 27        1
# 182       1
# 24        1
# 960       1
# 84        1
# 88        1
# Name: rating_numerator, dtype: int64

# %% [markdown]
# #### Quality Issue 5
# * There are some rating for numerators that are above 10 which is not right

# %%
# we view the twitter rating denominators to check if there are problems
twitter_archive_enhanced.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 20        2
# 80        2
# 70        1
# 7         1
# 15        1
# 150       1
# 170       1
# 0         1
# 90        1
# 40        1
# 130       1
# 110       1
# 16        1
# 120       1
# 2         1
# Name: rating_denominator, dtype: int64

# %%
#we view regualar expression that may be having conflicing values on the numerators or denominators
with pd.option_context('max_colwidth', 200):
    display(twitter_archive_enhanced[twitter_archive_enhanced['text'].str.contains(r"(\d+\.\d*\/\d+)")]
            [['tweet_id', 'text', 'rating_numerator', 'rating_denominator']])
# Out:
# C:\Users\Samuel\AppData\Local\Temp\ipykernel_195016\275478000.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   display(twitter_archive_enhanced[twitter_archive_enhanced['text'].str.contains(r"(\d+\.\d*\/\d+)")]
#                 tweet_id  \
# 45    883482846933004288
# 340   832215909146226688
# 695   786709082849828864
# 763   778027034220126208
# 1689  681340665377193984
# 1712  680494726643068929
#
#                                                                                                                                                                    text  \
# 45                             This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948
# 340                        RT @dog_rates: This is Logan, the Chow who lived. He solemnly swears he's up to lots of good. H*ckin magical af 9.75/10 https://t.co/yBO5wu…
# 695                                    This is Logan, the Chow who lived. He solemnly swears he's up to lots of good. H*ckin magical af 9.75/10 https://t.co/yBO5wuqaPS
# 763   This is Sophie. She's a Jubilant Bush Pupper. Super h*ckin rare. Appears at random just to smile at the locals. 11.27/10 would smile back https://t.co/QFaUiIHxHq
# 1689                                                         I've been told there's a slight possibility he's checking his mirror. We'll bump to 9.5/10. Still a menace
# 1712                                                         Here we have uncovered an entire battalion of holiday puppers. Average of 11.26/10 https://t.co/eNm2S6p9BD
#
#       rating_numerator  rating_denominator
# 45                   5                  10
# 340                 75                  10
# 695                 75                  10
# 763                 27                  10
# 1689                 5                  10
# 1712                26                  10

# %%
#we attempt to view the unique values of the dog age grouping
group=twitter_archive_enhanced[['tweet_id','doggo','floofer','pupper','puppo']]
group
# Out:
#                 tweet_id doggo floofer pupper puppo
# 0     892420643555336193  None    None   None  None
# 1     892177421306343426  None    None   None  None
# 2     891815181378084864  None    None   None  None
# 3     891689557279858688  None    None   None  None
# 4     891327558926688256  None    None   None  None
# ...                  ...   ...     ...    ...   ...
# 2351  666049248165822465  None    None   None  None
# 2352  666044226329800704  None    None   None  None
# 2353  666033412701032449  None    None   None  None
# 2354  666029285002620928  None    None   None  None
# 2355  666020888022790149  None    None   None  None
#
# [2356 rows x 5 columns]

# %%
with pd.option_context('max_colwidth', 200):
    display(twitter_archive_enhanced[['tweet_id', 'source']])
# Out:
#                 tweet_id  \
# 0     892420643555336193
# 1     892177421306343426
# 2     891815181378084864
# 3     891689557279858688
# 4     891327558926688256
# ...                  ...
# 2351  666049248165822465
# 2352  666044226329800704
# 2353  666033412701032449
# 2354  666029285002620928
# 2355  666020888022790149
#
#                                                                                   source
# 0     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...                                                                                  ...
# 2351  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2352  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2353  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2354  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2355  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# [2356 rows x 2 columns]

# %% [markdown]
# ## Image Prediction

# %%
#we view the image prediction value for the top 5 entries
image_prediction.sample(7)
# Out:
#                 tweet_id                                            jpg_url  \
# 148   668633411083464705    https://pbs.twimg.com/media/CUd2ieCUcAAexyT.jpg
# 1577  796116448414461957    https://pbs.twimg.com/media/CwxfrguUUAA1cbl.jpg
# 1719  819227688460238848    https://pbs.twimg.com/media/C157Oq3WQAEOyHm.jpg
# 1978  870656317836468226    https://pbs.twimg.com/media/DBUxSSTXsAA-Jn1.jpg
# 887   699072405256409088  https://pbs.twimg.com/ext_tw_video_thumb/69907...
# 1821  834574053763584002    https://pbs.twimg.com/media/C5UAqgyXAAAbMWH.jpg
# 1939  860563773140209665    https://pbs.twimg.com/media/C_FWL0vVwAA13N7.jpg
#
#       img_num              p1   p1_conf  p1_dog                p2   p2_conf  \
# 148         1        Pekinese  0.589011    True          Shih-Tzu  0.390987
# 1577        1        Cardigan  0.700182    True          Pembroke  0.260738
# 1719        1  Border_terrier  0.482452    True   German_shepherd  0.181082
# 1978        4        Pembroke  0.945495    True          Cardigan  0.045875
# 887         1        Shih-Tzu  0.599587    True          Pekinese  0.213069
# 1821        1   toilet_tissue  0.262936   False  golden_retriever  0.226564
# 1939        1        Cardigan  0.583936    True          Pembroke  0.055979
#
#       p2_dog                  p3   p3_conf  p3_dog
# 148     True    Japanese_spaniel  0.003310    True
# 1577    True            papillon  0.017110    True
# 1719    True  Norwegian_elkhound  0.065257    True
# 1978    True              beagle  0.004329    True
# 887     True         Maltese_dog  0.154293    True
# 1821    True             bathtub  0.078879   False
# 1939    True              beagle  0.045896    True

# %%
#we get the information of the dataset about the datatype,count and the total entries for tthe dataset
image_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
#we try to understand the dataset better by viewing the histogram for each coolumn 
image_prediction.hist(figsize=(12,13))
# Out:
# array([[<AxesSubplot:title={'center':'tweet_id'}>,
#         <AxesSubplot:title={'center':'img_num'}>],
#        [<AxesSubplot:title={'center':'p1_conf'}>,
#         <AxesSubplot:title={'center':'p2_conf'}>],
#        [<AxesSubplot:title={'center':'p3_conf'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#to check is there is null value in each column
image_prediction.isna().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %%
#to check if there is duplicated images in the column
image_prediction.jpg_url.duplicated(keep=False).value_counts()
# Out:
# False    1943
# True      132
# Name: jpg_url, dtype: int64

# %%
#To check for the count of each value in the image number column
image_prediction.img_num.value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %%
#check if there exist duplicates in the tweet id column
image_prediction.tweet_id.duplicated(keep=False).value_counts()
# Out:
# False    2075
# Name: tweet_id, dtype: int64

# %%
##check if there exist duplicates in the p1 dog column

image_prediction.p1_dog.duplicated(keep=False).sum()
# Out:
# 2075

# %%
##check if there exist duplicates in the p2 dog column

image_prediction.p2_dog.duplicated(keep=False).value_counts()
# Out:
# True    2075
# Name: p2_dog, dtype: int64

# %%
##check if there exist duplicates in the p3 dog column

image_prediction.p3_dog.duplicated(keep=False).value_counts()
# Out:
# True    2075
# Name: p3_dog, dtype: int64

# %%
#to check for values in p1_dog,p2_dog and p3_dog that are having false and otherwise
image_prediction[["p1_dog","p2_dog","p3_dog"]].apply(lambda x:
    (x[0] == False and x[1] == False and x[2] == False) 
    , axis = 1).value_counts()
# Out:
# False    1751
# True      324
# dtype: int64

# %% [markdown]
# ## Twitter API

# %%
twitter_api.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  891815181378084864           4328           25461
# 2  891327558926688256           9774           41048
# 3  890971913173991426           2158           12041
# 4  890609185150312448           4429           28226

# %%
twitter_api.sample(8)
# Out:
#                tweet_id  retweet_count  favorite_count
# 448  758854675097526272           1027            3904
# 617  712438159032893441           1756            5799
# 366  781308096455073793           2961            7973
# 564  729113531270991872            370            2054
# 353  785515384317313025           1477            6800
# 351  785927819176054784           3652           12696
# 195  826204788643753985           1075            5361
# 801  685906723014619143           3303            8277

# %%
# to view the information for the dataset
twitter_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177 entries, 0 to 1176
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        1177 non-null   int64
#  1   retweet_count   1177 non-null   int64
#  2   favorite_count  1177 non-null   int64
# dtypes: int64(3)
# memory usage: 27.7 KB

# %%
#to ccheck if there is null values in the dataset
twitter_api.isna().sum()
# Out:
# tweet_id          0
# retweet_count     0
# favorite_count    0
# dtype: int64

# %%
# check for duplicates on the tweet id column
twitter_api.tweet_id.duplicated().sum()
# Out:
# 0

# %%
#to check the shape of the dataset
twitter_api.shape
# Out:
# (1177, 3)

# %% [markdown]
# ### Quality Issue
#
# * twitter_archive_enhanced- Null values for column 2,3,7,8,9
# * twitter_archive_enhanced- incomplete data for index 1,2,6,7,8,9
# * twitter_archive_enhanced- retweet status id have duplictes
# * twitter_archive_enhanced- there are empty values in 6 columns
# * twitter_archive_enhanced- incorrect datatype for index 8
# * twitter_archive_enhanced-- All the tweet id are unique so no duplicate* the above contain records of rating of numerators that were not correctly recorded
# * twitter_archive_enhanced- split of the retweeted_status_timestamp column
# * twitter_archive_enhanced- replacing the datatype of  the retweeted_status_timestamp
# * image prediction- the names of (p1,p2,p3) are having underscore hence it may  not be easy to understand
# * image prediction- Some of the images have duplicates
# * image-prediction- The img_num column wasn't important

# %% [markdown]
# ### Tidyness Issues for twitter_archive_enhanced
#
# * twitter_archive_enhanced- The dog age group could have been merged to reduce the number of column
# * twitter_archive_enhanced- The source column need only the source of information not the whole link
# * image_prediction- uncatogorising of the p1,p2,p3 values
# * image_prediction- p1_conf,p2_conf,p3_conf should have been grouped

# %% [markdown]
# # CLEANING

# %% [markdown]
# ## twitter_archive_enhanced

# %%
# making a copy of all three dataset this dataset for reference purpose
twitter_archive_enhanced_cleaning=twitter_archive_enhanced.copy()
image_prediction_cleaning=image_prediction.copy()
twitter_api_cleaning=twitter_api.copy()

# %% [markdown]
# ## Define
# * Drop all columns that are not important for this analysis

# %% [markdown]
# ## Code

# %%
#we drop all unneessary columns to reduce the size
twitter_archive_enhanced_cleaning=twitter_archive_enhanced_cleaning.drop(['in_reply_to_status_id','in_reply_to_user_id','source','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp','expanded_urls'],axis=1)

# %% [markdown]
# ## Test

# %%
twitter_archive_enhanced_cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   object
#  2   text                2356 non-null   object
#  3   rating_numerator    2356 non-null   int64
#  4   rating_denominator  2356 non-null   int64
#  5   name                2356 non-null   object
#  6   doggo               2356 non-null   object
#  7   floofer             2356 non-null   object
#  8   pupper              2356 non-null   object
#  9   puppo               2356 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 184.2+ KB

# %% [markdown]
# ## Define
# * Change the values of the numerator rating column that are not correct

# %% [markdown]
# ## Code

# %%
with pd.option_context('max_colwidth', 200):
    display(twitter_archive_enhanced_cleaning[twitter_archive_enhanced_cleaning['text'].str.contains(r"(\d+\.\d*\/\d+)")]
            [['tweet_id', 'text', 'rating_numerator', 'rating_denominator']])
# Out:
# C:\Users\Samuel\AppData\Local\Temp\ipykernel_195016\1042792891.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   display(twitter_archive_enhanced_cleaning[twitter_archive_enhanced_cleaning['text'].str.contains(r"(\d+\.\d*\/\d+)")]
#                 tweet_id  \
# 45    883482846933004288
# 340   832215909146226688
# 695   786709082849828864
# 763   778027034220126208
# 1689  681340665377193984
# 1712  680494726643068929
#
#                                                                                                                                                                    text  \
# 45                             This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948
# 340                        RT @dog_rates: This is Logan, the Chow who lived. He solemnly swears he's up to lots of good. H*ckin magical af 9.75/10 https://t.co/yBO5wu…
# 695                                    This is Logan, the Chow who lived. He solemnly swears he's up to lots of good. H*ckin magical af 9.75/10 https://t.co/yBO5wuqaPS
# 763   This is Sophie. She's a Jubilant Bush Pupper. Super h*ckin rare. Appears at random just to smile at the locals. 11.27/10 would smile back https://t.co/QFaUiIHxHq
# 1689                                                         I've been told there's a slight possibility he's checking his mirror. We'll bump to 9.5/10. Still a menace
# 1712                                                         Here we have uncovered an entire battalion of holiday puppers. Average of 11.26/10 https://t.co/eNm2S6p9BD
#
#       rating_numerator  rating_denominator
# 45                   5                  10
# 340                 75                  10
# 695                 75                  10
# 763                 27                  10
# 1689                 5                  10
# 1712                26                  10

# %%
# we manuallyy change the numerators that are wrongly gathered based on the values on the text
twitter_archive_enhanced_cleaning.loc[twitter_archive_enhanced_cleaning.tweet_id==883482846933004288,'rating_numerator']=13.5
twitter_archive_enhanced_cleaning.loc[twitter_archive_enhanced_cleaning.tweet_id==681340665377193984,'rating_numerator']=9.5
twitter_archive_enhanced_cleaning.loc[twitter_archive_enhanced_cleaning.tweet_id==680494726643068929,'rating_numerator']=11.26
twitter_archive_enhanced_cleaning.loc[twitter_archive_enhanced_cleaning.tweet_id==786709082849828864,'rating_numerator']=9.75
twitter_archive_enhanced_cleaning.loc[twitter_archive_enhanced_cleaning.tweet_id==778027034220126208,'rating_numerator']=11.27

# %% [markdown]
# ## Test

# %%
with pd.option_context('max_colwidth', 200):
    display(twitter_archive_enhanced_cleaning[twitter_archive_enhanced_cleaning['text'].str.contains(r"(\d+\.\d*\/\d+)")]
            [['tweet_id', 'text', 'rating_numerator', 'rating_denominator']])
# Out:
# C:\Users\Samuel\AppData\Local\Temp\ipykernel_195016\1042792891.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   display(twitter_archive_enhanced_cleaning[twitter_archive_enhanced_cleaning['text'].str.contains(r"(\d+\.\d*\/\d+)")]
#                 tweet_id  \
# 45    883482846933004288
# 340   832215909146226688
# 695   786709082849828864
# 763   778027034220126208
# 1689  681340665377193984
# 1712  680494726643068929
#
#                                                                                                                                                                    text  \
# 45                             This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948
# 340                        RT @dog_rates: This is Logan, the Chow who lived. He solemnly swears he's up to lots of good. H*ckin magical af 9.75/10 https://t.co/yBO5wu…
# 695                                    This is Logan, the Chow who lived. He solemnly swears he's up to lots of good. H*ckin magical af 9.75/10 https://t.co/yBO5wuqaPS
# 763   This is Sophie. She's a Jubilant Bush Pupper. Super h*ckin rare. Appears at random just to smile at the locals. 11.27/10 would smile back https://t.co/QFaUiIHxHq
# 1689                                                         I've been told there's a slight possibility he's checking his mirror. We'll bump to 9.5/10. Still a menace
# 1712                                                         Here we have uncovered an entire battalion of holiday puppers. Average of 11.26/10 https://t.co/eNm2S6p9BD
#
#       rating_numerator  rating_denominator
# 45               13.50                  10
# 340              75.00                  10
# 695               9.75                  10
# 763              11.27                  10
# 1689              9.50                  10
# 1712             11.26                  10

# %% [markdown]
# ## Define
# * we create a rating column which is the division of the nemerator and denomiator

# %% [markdown]
# ## Code

# %%
twitter_archive_enhanced_cleaning['rating']=twitter_archive_enhanced_cleaning.rating_numerator/twitter_archive_enhanced_cleaning.rating_denominator

# %% [markdown]
# ## Test

# %%
twitter_archive_enhanced_cleaning.sample(7)
# Out:
#                 tweet_id                  timestamp  \
# 1694  681281657291280384  2015-12-28 01:12:59 +0000
# 1188  718454725339934721  2016-04-08 15:05:29 +0000
# 624   795464331001561088  2016-11-07 03:14:10 +0000
# 1082  738883359779196928  2016-06-04 00:01:35 +0000
# 1241  712065007010385924  2016-03-21 23:55:01 +0000
# 1899  674670581682434048  2015-12-09 19:22:56 +0000
# 2164  669371483794317312  2015-11-25 04:26:12 +0000
#
#                                                    text  rating_numerator  \
# 1694  Meet Sarge. His parents signed him up for danc...              11.0
# 1188  This pic is old but I hadn't seen it until tod...              13.0
# 624   Elder doggo does a splash. Both 13/10 incredib...              13.0
# 1082  When a single soap orb changes your entire per...              10.0
# 1241  This is Chester. He's clearly in charge of the...               6.0
# 1899  Meet Jeb &amp; Bush. Jeb is somehow stuck in t...               9.0
# 2164  This is Oliviér. He's a Baptist Hindquarter. A...              10.0
#
#       rating_denominator     name  doggo floofer pupper puppo  rating
# 1694                  10    Sarge   None    None   None  None     1.1
# 1188                  10     None   None    None   None  None     1.3
# 624                   10     None  doggo    None   None  None     1.3
# 1082                  10     None   None    None   None  None     1.0
# 1241                  10  Chester   None    None   None  None     0.6
# 1899                  10      Jeb   None    None   None  None     0.9
# 2164                  10  Oliviér   None    None   None  None     1.0

# %% [markdown]
# ## Define
#
# * Create a column which conatins  the differnt age group of the dogs

# %% [markdown]
# ## Code

# %%
twitter_archive_enhanced_cleaning=pd.melt(twitter_archive_enhanced_cleaning,id_vars=['tweet_id','timestamp','text','rating_numerator','rating_denominator','name','rating'],value_vars=['doggo','floofer','pupper','puppo'],value_name='dog_group')

# %%
twitter_archive_enhanced_cleaning.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...              13.0
# 1  This is Tilly. She's just checking pup on you....              13.0
# 2  This is Archie. He is a rare Norwegian Pouncin...              12.0
# 3  This is Darla. She commenced a snooze mid meal...              13.0
# 4  This is Franklin. He would like you to stop ca...              12.0
#
#    rating_denominator      name  rating variable dog_group
# 0                  10   Phineas     1.3    doggo      None
# 1                  10     Tilly     1.3    doggo      None
# 2                  10    Archie     1.2    doggo      None
# 3                  10     Darla     1.3    doggo      None
# 4                  10  Franklin     1.2    doggo      None

# %% [markdown]
# ## Define
#
# * we  drop the variable column

# %% [markdown]
# ## Code

# %%
twitter_archive_enhanced_cleaning.drop('variable', inplace=True,axis=1)

# %% [markdown]
# ## Test

# %%
twitter_archive_enhanced_cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9424 entries, 0 to 9423
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            9424 non-null   int64
#  1   timestamp           9424 non-null   object
#  2   text                9424 non-null   object
#  3   rating_numerator    9424 non-null   float64
#  4   rating_denominator  9424 non-null   int64
#  5   name                9424 non-null   object
#  6   rating              9424 non-null   float64
#  7   dog_group           9424 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 589.1+ KB

# %% [markdown]
# ## Define
# * Drop all duplicates that exist because of the dog_group column created

# %% [markdown]
# ## Code

# %%
twitter_archive_enhanced_cleaning=twitter_archive_enhanced_cleaning.sort_values('dog_group')

# %%
twitter_archive_enhanced_cleaning=twitter_archive_enhanced_cleaning.drop_duplicates(subset='tweet_id', keep='last')

# %% [markdown]
# ## Test

# %%
twitter_archive_enhanced_cleaning.dog_group.value_counts()
# Out:
# None       1976
# pupper      257
# doggo        83
# puppo        30
# floofer      10
# Name: dog_group, dtype: int64

# %%
twitter_archive_enhanced_cleaning.head()
# Out:
#                 tweet_id                  timestamp  \
# 2259  667550904950915073  2015-11-20 03:51:52 +0000
# 2260  667550882905632768  2015-11-20 03:51:47 +0000
# 2261  667549055577362432  2015-11-20 03:44:31 +0000
# 2262  667546741521195010  2015-11-20 03:35:20 +0000
# 2263  667544320556335104  2015-11-20 03:25:43 +0000
#
#                                                    text  rating_numerator  \
# 2259  RT @dogratingrating: Exceptional talent. Origi...              12.0
# 2260  RT @dogratingrating: Unoriginal idea. Blatant ...               5.0
# 2261  Never seen dog like this. Breathes heavy. Tilt...               1.0
# 2262  Here is George. George took a selfie of his ne...               9.0
# 2263  This is Kial. Kial is either wearing a cape, w...              10.0
#
#       rating_denominator    name  rating dog_group
# 2259                  10    None     1.2      None
# 2260                  10    None     0.5      None
# 2261                  10    None     0.1      None
# 2262                  10  George     0.9      None
# 2263                  10    Kial     1.0      None

# %%
twitter_archive_enhanced_cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 2259 to 7236
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   object
#  2   text                2356 non-null   object
#  3   rating_numerator    2356 non-null   float64
#  4   rating_denominator  2356 non-null   int64
#  5   name                2356 non-null   object
#  6   rating              2356 non-null   float64
#  7   dog_group           2356 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 165.7+ KB

# %% [markdown]
# #### Image Prediction

# %%
#we view randomly the image prediction dataset
image_prediction_cleaning.sample(10)
# Out:
#                 tweet_id                                            jpg_url  \
# 1912  853760880890318849    https://pbs.twimg.com/media/C9kq_bbVwAAuRZd.jpg
# 1424  772152991789019136    https://pbs.twimg.com/media/Crc9DEoWEAE7RLH.jpg
# 704   684926975086034944    https://pbs.twimg.com/media/CYFZXdiU0AAc_kw.jpg
# 1564  793614319594401792    https://pbs.twimg.com/media/CvyVxQRWEAAdSZS.jpg
# 1670  813081950185472002    https://pbs.twimg.com/media/C0ilsa1XUAEHK_k.jpg
# 880   698635131305795584  https://pbs.twimg.com/ext_tw_video_thumb/69863...
# 1017  709918798883774466    https://pbs.twimg.com/media/CdojYQmW8AApv4h.jpg
# 1389  766423258543644672    https://pbs.twimg.com/media/CqLh4yJWcAAHomv.jpg
# 444   674644256330530816    https://pbs.twimg.com/media/CVzRXmXWIAA0Fkr.jpg
# 1230  745712589599014916    https://pbs.twimg.com/media/CllNnkWWMAEDIAR.jpg
#
#       img_num                  p1   p1_conf  p1_dog                  p2  \
# 1912        1  miniature_pinscher  0.292519    True           Chihuahua
# 1424        2    golden_retriever  0.275318    True        Irish_setter
# 704         1  Labrador_retriever  0.769412    True    golden_retriever
# 1564        1    golden_retriever  0.705092    True  Labrador_retriever
# 1670        2            Doberman  0.909951    True              kelpie
# 880         1             Samoyed  0.158464    True              kuvasz
# 1017        2            Pembroke  0.956222    True            Cardigan
# 1389        2            keeshond  0.995823    True          Pomeranian
# 444         1         soccer_ball  0.398102   False              basset
# 1230        1           seat_belt  0.379055   False                chow
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 1912  0.120946    True                   Rottweiler  0.119490    True
# 1424  0.100988    True                       vizsla  0.073525    True
# 704   0.144893    True                         lion  0.021440   False
# 1564  0.219721    True                       kuvasz  0.015965    True
# 1670  0.042649    True           miniature_pinscher  0.023004    True
# 880   0.089402    True  West_Highland_white_terrier  0.025037    True
# 1017  0.020727    True                    Chihuahua  0.007912    True
# 1389  0.003897    True           Norwegian_elkhound  0.000253    True
# 444   0.335692    True               cocker_spaniel  0.072941    True
# 1230  0.062754    True                      minibus  0.052423   False

# %% [markdown]
# ## Define
# * Create dog_breed that checks for the best predicted value is p1 then prints it else it checks for it and print it

# %% [markdown]
# ## Code

# %%
def predicted_image(image_prediction_cleaning):
    if image_prediction_cleaning.p1_dog==True:
        return image_prediction_cleaning.p1
    elif image_prediction_cleaning.p2_dog==True:
        return image_prediction_cleaning.p2
    elif image_prediction_cleaning.p3_dog==True:
        return image_prediction_cleaning.p3
    else:
        return 'Error'

# %% [markdown]
# # Test

# %%
image_prediction_cleaning['dog_breed']=image_prediction_cleaning.apply(predicted_image,axis=1)

# %% [markdown]
# ## Define
# * Create dog_breed that checks for the best predicted confidence level is p1 then prints it's value else it checks for others

# %% [markdown]
# ## Code

# %%
def predicted_confidence(image_prediction_cleaning):
    if image_prediction_cleaning['p1_dog']==True:
        return image_prediction_cleaning.p1_conf
    elif image_prediction_cleaning.p2_dog==True:
        return image_prediction_cleaning.p2_conf
    elif image_prediction_cleaning.p3_dog==True:
        return image_prediction_cleaning.p3_conf
    else:
        return 'error'

# %% [markdown]
# ## Test

# %%
image_prediction_cleaning['Confidence_level']=image_prediction_cleaning.apply(predicted_confidence,axis=1)

# %%
image_prediction_cleaning.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 280   671115716440031232  https://pbs.twimg.com/media/CVBILUgVAAA1ZUr.jpg
# 177   669214165781868544  https://pbs.twimg.com/media/CUmGu7-UcAA0r3O.jpg
# 288   671159727754231808  https://pbs.twimg.com/media/CVBwNjVWwAAlUFQ.jpg
# 359   672622327801233409  https://pbs.twimg.com/media/CVWicBbUYAIomjC.jpg
# 509   676101918813499392  https://pbs.twimg.com/media/CWH_FTgWIAAwOUy.jpg
# 773   689599056876867584  https://pbs.twimg.com/media/CZHyrvOXEAEin-A.jpg
# 857   696877980375769088  https://pbs.twimg.com/media/CavO0uuWEAE96Ed.jpg
# 233   670420569653809152  https://pbs.twimg.com/media/CU3P82RWEAAIVrE.jpg
# 1834  836989968035819520  https://pbs.twimg.com/media/C52V7PzWcAA_pVv.jpg
# 134   668484198282485761  https://pbs.twimg.com/media/CUbu1GAWsAEH3E-.jpg
#
#       img_num                p1   p1_conf  p1_dog                  p2  \
# 280         1          malinois  0.406341    True              kelpie
# 177         1           minivan  0.435396   False          police_van
# 288         1           pitcher  0.117446   False          sunglasses
# 359         1  golden_retriever  0.952773    True  Labrador_retriever
# 509         1          Shih-Tzu  0.225848    True     Norfolk_terrier
# 773         1           dogsled  0.426494   False      cocker_spaniel
# 857         1      space_heater  0.206876   False             spatula
# 233         1           bow_tie  0.268759   False            cardigan
# 1834        1     shopping_cart  0.572422   False     shopping_basket
# 134         1   standard_poodle  0.587372    True  Bedlington_terrier
#
#        p2_conf  p2_dog             p3   p3_conf  p3_dog         dog_breed  \
# 280   0.143366    True          dingo  0.129802   False          malinois
# 177   0.310143   False        minibus  0.068201   False             Error
# 288   0.062487   False           mask  0.059517   False             Error
# 359   0.010835    True        clumber  0.008786    True  golden_retriever
# 509   0.186873    True  Irish_terrier  0.106987    True          Shih-Tzu
# 773   0.073101    True      Chihuahua  0.070323    True    cocker_spaniel
# 857   0.123450   False         vacuum  0.119218   False             Error
# 233   0.153957   False            wig  0.072295   False             Error
# 1834  0.414002   False     toy_poodle  0.005887    True        toy_poodle
# 134   0.182411    True   Afghan_hound  0.040968    True   standard_poodle
#
#      Confidence_level
# 280          0.406341
# 177             error
# 288             error
# 359          0.952773
# 509          0.225848
# 773          0.073101
# 857             error
# 233             error
# 1834         0.005887
# 134          0.587372

# %% [markdown]
# ## Define
# * We  remove error values in the dog_breed column

# %% [markdown]
# ## Code

# %%
image_prediction_cleaning=image_prediction_cleaning.loc[image_prediction_cleaning['dog_breed']!= 'Error']

# %% [markdown]
# ## Test

# %%
image_prediction_cleaning.dog_breed.value_counts()
# Out:
# golden_retriever        173
# Labrador_retriever      113
# Pembroke                 96
# Chihuahua                95
# pug                      65
#                        ...
# Scotch_terrier            1
# EntleBucher               1
# Japanese_spaniel          1
# standard_schnauzer        1
# Bouvier_des_Flandres      1
# Name: dog_breed, Length: 113, dtype: int64

# %%
image_prediction_cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1751 entries, 0 to 2073
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_id          1751 non-null   int64
#  1   jpg_url           1751 non-null   object
#  2   img_num           1751 non-null   int64
#  3   p1                1751 non-null   object
#  4   p1_conf           1751 non-null   float64
#  5   p1_dog            1751 non-null   bool
#  6   p2                1751 non-null   object
#  7   p2_conf           1751 non-null   float64
#  8   p2_dog            1751 non-null   bool
#  9   p3                1751 non-null   object
#  10  p3_conf           1751 non-null   float64
#  11  p3_dog            1751 non-null   bool
#  12  dog_breed         1751 non-null   object
#  13  Confidence_level  1751 non-null   object
# dtypes: bool(3), float64(3), int64(2), object(6)
# memory usage: 169.3+ KB

# %%
# we check for the list of the dataset so as to nable us drop unecessary columns
list(image_prediction_cleaning)
# Out:
# ['tweet_id',
#  'jpg_url',
#  'img_num',
#  'p1',
#  'p1_conf',
#  'p1_dog',
#  'p2',
#  'p2_conf',
#  'p2_dog',
#  'p3',
#  'p3_conf',
#  'p3_dog',
#  'dog_breed',
#  'Confidence_level']

# %%
best_prediction = image_prediction_cleaning.groupby(['p1_dog'])['p1_dog'].count()

# %% [markdown]
# ## Define
# * Drop all columns that we will not be using

# %% [markdown]
# ## Code

# %%
# we dropp all columns that we will not be using
image_prediction_cleaning=image_prediction_cleaning.drop(columns={'p1',
 'p1_conf',
 'p1_dog',
 'p2',
 'p2_conf',
 'p2_dog',
 'p3',
 'p3_conf',
 'p3_dog'},axis=1)

# %% [markdown]
# ## Test

# %%
image_prediction_cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1751 entries, 0 to 2073
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_id          1751 non-null   int64
#  1   jpg_url           1751 non-null   object
#  2   img_num           1751 non-null   int64
#  3   dog_breed         1751 non-null   object
#  4   Confidence_level  1751 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 82.1+ KB

# %% [markdown]
# ## Twitter API

# %%
twitter_api_cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177 entries, 0 to 1176
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        1177 non-null   int64
#  1   retweet_count   1177 non-null   int64
#  2   favorite_count  1177 non-null   int64
# dtypes: int64(3)
# memory usage: 27.7 KB

# %%
twitter_api_cleaning.describe()
# Out:
#            tweet_id  retweet_count  favorite_count
# count  1.177000e+03    1177.000000     1177.000000
# mean   7.427463e+17    3222.255735     8260.755310
# std    6.856773e+16    5106.835873    12088.982006
# min    6.660293e+17       0.000000        0.000000
# 25%    6.783997e+17     634.000000     1499.000000
# 50%    7.195514e+17    1483.000000     3705.000000
# 75%    7.993088e+17    3737.000000    10202.000000
# max    8.924206e+17   52360.000000   132810.000000

# %% [markdown]
# ## STORING

# %% [markdown]
# ## Define
# * We create a new datframe that is used to merge the three dataset

# %% [markdown]
# ## Code

# %%
df=pd.merge(twitter_archive_enhanced_cleaning,image_prediction_cleaning, on='tweet_id',how='outer').merge( twitter_api, on='tweet_id',how='outer')

# %% [markdown]
# ## Test

# %%
df.head()
# Out:
#              tweet_id                  timestamp  \
# 0  667550904950915073  2015-11-20 03:51:52 +0000
# 1  667550882905632768  2015-11-20 03:51:47 +0000
# 2  667549055577362432  2015-11-20 03:44:31 +0000
# 3  667546741521195010  2015-11-20 03:35:20 +0000
# 4  667544320556335104  2015-11-20 03:25:43 +0000
#
#                                                 text  rating_numerator  \
# 0  RT @dogratingrating: Exceptional talent. Origi...              12.0
# 1  RT @dogratingrating: Unoriginal idea. Blatant ...               5.0
# 2  Never seen dog like this. Breathes heavy. Tilt...               1.0
# 3  Here is George. George took a selfie of his ne...               9.0
# 4  This is Kial. Kial is either wearing a cape, w...              10.0
#
#    rating_denominator    name  rating dog_group  \
# 0                  10    None     1.2      None
# 1                  10    None     0.5      None
# 2                  10    None     0.1      None
# 3                  10  George     0.9      None
# 4                  10    Kial     1.0      None
#
#                                            jpg_url  img_num   dog_breed  \
# 0  https://pbs.twimg.com/media/CUOb_gUUkAACXdS.jpg      1.0      vizsla
# 1                                              NaN      NaN         NaN
# 2                                              NaN      NaN         NaN
# 3  https://pbs.twimg.com/media/CUOaOWXWcAA0_Jy.jpg      1.0  toy_poodle
# 4  https://pbs.twimg.com/media/CUOYBbbWIAAXQGU.jpg      1.0  Pomeranian
#
#   Confidence_level  retweet_count  favorite_count
# 0         0.000081            NaN             NaN
# 1              NaN           34.0             0.0
# 2              NaN            NaN             NaN
# 3         0.787424          138.0           355.0
# 4         0.412893            NaN             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   object
#  2   text                2356 non-null   object
#  3   rating_numerator    2356 non-null   float64
#  4   rating_denominator  2356 non-null   int64
#  5   name                2356 non-null   object
#  6   rating              2356 non-null   float64
#  7   dog_group           2356 non-null   object
#  8   jpg_url             1751 non-null   object
#  9   img_num             1751 non-null   float64
#  10  dog_breed           1751 non-null   object
#  11  Confidence_level    1751 non-null   object
#  12  retweet_count       1177 non-null   float64
#  13  favorite_count      1177 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 276.1+ KB

# %% [markdown]
# ## Define
# * We drop duplicates of the tweet_id

# %% [markdown]
# ## Code

# %%
df=df.drop_duplicates('tweet_id')

# %% [markdown]
# ## Test

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   object
#  2   text                2356 non-null   object
#  3   rating_numerator    2356 non-null   float64
#  4   rating_denominator  2356 non-null   int64
#  5   name                2356 non-null   object
#  6   rating              2356 non-null   float64
#  7   dog_group           2356 non-null   object
#  8   jpg_url             1751 non-null   object
#  9   img_num             1751 non-null   float64
#  10  dog_breed           1751 non-null   object
#  11  Confidence_level    1751 non-null   object
#  12  retweet_count       1177 non-null   float64
#  13  favorite_count      1177 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 276.1+ KB

# %%
#we check if the text has duplicates then we count them
df.text.duplicated().value_counts()
# Out:
# False    2356
# Name: text, dtype: int64

# %% [markdown]
# ## Define
# * Store the new datset into a new file termed twitter_archive_master_csv

# %% [markdown]
# ## Code

# %%
df.to_csv('twitter_archive_master',index=False,header=False,encoding='utf-8')

# %% [markdown]
# ## Test

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   object
#  2   text                2356 non-null   object
#  3   rating_numerator    2356 non-null   float64
#  4   rating_denominator  2356 non-null   int64
#  5   name                2356 non-null   object
#  6   rating              2356 non-null   float64
#  7   dog_group           2356 non-null   object
#  8   jpg_url             1751 non-null   object
#  9   img_num             1751 non-null   float64
#  10  dog_breed           1751 non-null   object
#  11  Confidence_level    1751 non-null   object
#  12  retweet_count       1177 non-null   float64
#  13  favorite_count      1177 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 276.1+ KB

# %%
df.retweet_count.isna().sum()
# Out:
# 1179

# %% [markdown]
# ## Analysis

# %%
#We checks for the counts of each dog age group
df.dog_group.value_counts()
# Out:
# None       1976
# pupper      257
# doggo        83
# puppo        30
# floofer      10
# Name: dog_group, dtype: int64

# %%
df2=df.query("dog_breed=='golden_retriever'")
df2.jpg_url.sample(4)
# Out:
# 1510    https://pbs.twimg.com/media/DBQwlFCXkAACSkI.jpg
# 409     https://pbs.twimg.com/media/CZX8nyeVAAEstKM.jpg
# 384     https://pbs.twimg.com/media/CX7br3HWsAAQ9L1.jpg
# 1971    https://pbs.twimg.com/media/CtKHLuCWYAA2TTs.jpg
# Name: jpg_url, dtype: object

# %%
Image(url=' https://pbs.twimg.com/media/CfN23ArXEAEkZkz.jpg')
# Out:
# <img src=" https://pbs.twimg.com/media/CfN23ArXEAEkZkz.jpg"/>

# %%
df3=df.query("dog_breed=='Scotch_terrier'")
df3.jpg_url.sample(1)
# Out:
# 448    https://pbs.twimg.com/media/CZDT-mZWsAEK9BH.jpg
# Name: jpg_url, dtype: object

# %%
Image(url='https://pbs.twimg.com/media/CZDT-mZWsAEK9BH.jpg')
# Out:
# <img src="https://pbs.twimg.com/media/CZDT-mZWsAEK9BH.jpg"/>

# %%
#we plot a barh chart to show the top 10 dog breeds based on rating
import plotly.express as px
colour=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]
df_bar=df.groupby(['dog_breed'])['rating'].size().to_frame().sort_values(['rating'],ascending=False).head(10).reset_index().plot.barh(x='dog_breed',y='rating',color=colour,legend=False)
plt.xlabel=('rating for dog breeds')
plt.ylabel=('dog breed')
plt.title('Histogram showing top ten(10) dog breed per rating')
# Out:
# Text(0.5, 1.0, 'Histogram showing top ten(10) dog breed per rating')

# %%
#we plot a barh chart to show the top 10 dog breeds based on rating
import plotly.express as px
colour=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]
df_bar=df.groupby(['dog_breed'])['rating'].size().to_frame().sort_values(['rating'],ascending=False).tail(10).reset_index().plot.barh(x='dog_breed',y='rating',color=colour,legend=False)
plt.xlabel=('rating for dog breeds')
plt.ylabel=('dog breed')
plt.title('Histogram showing bottom ten(10) dog breed per rating')
# Out:
# Text(0.5, 1.0, 'Histogram showing bottom ten(10) dog breed per rating')

# %%
df.groupby(['dog_breed','favorite_count']).size().to_frame().sort_values(['favorite_count'],ascending=False).head(10).reset_index().plot.bar(y='favorite_count',x='dog_breed',legend=False)
plt.ylabel=('favorite count for dog breeds')
plt.xlabel=('dog breed')
plt.title('Bar chart showing top ten(10) dog breed per favorite count')
# Out:
# Text(0.5, 1.0, 'Bar chart showing top ten(10) dog breed per favorite count')

# %%
df.groupby(['dog_breed','retweet_count']).size().to_frame().sort_values(['retweet_count'],ascending=False).head(10).reset_index().plot.bar(y='retweet_count',x='dog_breed',legend=False)
plt.ylabel=('retweet count for dog breeds')
plt.xlabel=('dog breed')
plt.title('Bar chart showing top ten(10) dog breed per retweet count')
# Out:
# Text(0.5, 1.0, 'Bar chart showing top ten(10) dog breed per retweet count')

# %%
#we describe the data based on the dog group which will show the mean,median,standard deviation etc for each column
df.groupby('dog_breed').describe().sort_values(['dog_breed'],ascending=False).head(20).reset_index()
# Out:
#                       dog_breed tweet_id                              \
#                                    count          mean           std
# 0       wire-haired_fox_terrier      2.0  7.712716e+17  3.104838e+16
# 1                       whippet     11.0  7.424905e+17  8.197479e+16
# 2                        vizsla     14.0  7.417263e+17  7.746069e+16
# 3                   toy_terrier      3.0  7.166375e+17  8.353425e+16
# 4                    toy_poodle     52.0  7.219281e+17  5.140789e+16
# 5            standard_schnauzer      1.0  6.757109e+17           NaN
# 6               standard_poodle     12.0  7.471502e+17  6.372101e+16
# 7   soft-coated_wheaten_terrier     15.0  7.038616e+17  4.393623e+16
# 8                 silky_terrier      1.0  7.737047e+17           NaN
# 9                    schipperke     15.0  7.389692e+17  6.438302e+16
# 10                      redbone      6.0  7.103190e+17  4.646675e+16
# 11                          pug     65.0  7.201528e+17  6.196293e+16
# 12                     papillon      8.0  7.203468e+17  4.691528e+16
# 13          miniature_schnauzer      5.0  7.014763e+17  6.568751e+16
# 14             miniature_poodle      8.0  7.151542e+17  6.153907e+16
# 15           miniature_pinscher     26.0  7.345660e+17  6.637056e+16
# 16                     malinois     11.0  7.199779e+17  5.806896e+16
# 17                     malamute     34.0  7.486789e+17  6.754450e+16
# 18                       kuvasz     19.0  7.314310e+17  6.123118e+16
# 19                     komondor      3.0  7.774009e+17  1.022299e+17
#
#                                                                           \
#              min           25%           50%           75%           max
# 0   7.493170e+17  7.602943e+17  7.712716e+17  7.822488e+17  7.932261e+17
# 1   6.703857e+17  6.795164e+17  7.077415e+17  7.927156e+17  8.892788e+17
# 2   6.671780e+17  6.749385e+17  7.155289e+17  7.999547e+17  8.790082e+17
# 3   6.664188e+17  6.684229e+17  6.704270e+17  7.417469e+17  8.130668e+17
# 4   6.671522e+17  6.737691e+17  7.073259e+17  7.552183e+17  8.369900e+17
# 5   6.757109e+17  6.757109e+17  6.757109e+17  6.757109e+17  6.757109e+17
# 6   6.684842e+17  6.862912e+17  7.467861e+17  7.994141e+17  8.512249e+17
# 7   6.663738e+17  6.737976e+17  6.929016e+17  7.168097e+17  8.349316e+17
# 8   7.737047e+17  7.737047e+17  7.737047e+17  7.737047e+17  7.737047e+17
# 9   6.732130e+17  6.805473e+17  7.088458e+17  7.922573e+17  8.494123e+17
# 10  6.660293e+17  6.693604e+17  7.054645e+17  7.475370e+17  7.660692e+17
# 11  6.660829e+17  6.739569e+17  6.925353e+17  7.490644e+17  8.862584e+17
# 12  6.673934e+17  6.878964e+17  7.006807e+17  7.550059e+17  7.983407e+17
# 13  6.668178e+17  6.686314e+17  6.688727e+17  6.848002e+17  8.182595e+17
# 14  6.660586e+17  6.702017e+17  6.774673e+17  7.684957e+17  8.145302e+17
# 15  6.660492e+17  6.744938e+17  7.125994e+17  7.898675e+17  8.800958e+17
# 16  6.688261e+17  6.738613e+17  6.997796e+17  7.536925e+17  8.228591e+17
# 17  6.663533e+17  6.853753e+17  7.393977e+17  8.075376e+17  8.851676e+17
# 18  6.677282e+17  6.905517e+17  7.074206e+17  7.535416e+17  8.867369e+17
# 19  6.686367e+17  7.303434e+17  7.920501e+17  8.317830e+17  8.715159e+17
#
#    rating_numerator  ... retweet_count          favorite_count                \
#               count  ...           75%      max          count          mean
# 0               2.0  ...       3130.75   3338.0            2.0   8538.500000
# 1              11.0  ...      16342.50  31989.0            3.0  24022.666667
# 2              14.0  ...       2516.00   4046.0            4.0   6027.750000
# 3               3.0  ...       1751.75   2276.0            2.0   4708.000000
# 4              52.0  ...       2423.25  21324.0           26.0   6264.692308
# 5               1.0  ...           NaN      NaN            0.0           NaN
# 6              12.0  ...       1795.00  42228.0            9.0  15423.777778
# 7              15.0  ...       1059.75   1799.0            8.0   2126.500000
# 8               1.0  ...       1891.00   1891.0            1.0   7317.000000
# 9              15.0  ...       6620.50   9299.0            7.0   9347.142857
# 10              6.0  ...        647.00   1003.0            3.0   1835.666667
# 11             65.0  ...       2243.00   9193.0           37.0   5236.432432
# 12              8.0  ...         60.00     60.0            1.0    211.000000
# 13              5.0  ...        736.50   1124.0            3.0   1427.333333
# 14              8.0  ...       1494.25   1972.0            2.0   2035.000000
# 15             26.0  ...       5279.25  11131.0           10.0   8525.800000
# 16             11.0  ...       1464.00   1905.0            4.0   3453.500000
# 17             34.0  ...       4426.25  25661.0           18.0  13206.833333
# 18             19.0  ...       2348.00   4795.0           16.0   5520.187500
# 19              3.0  ...       1698.00   2088.0            2.0   4571.500000
#
#
#              std     min      25%      50%       75%      max
# 0    3482.500897  6076.0  7307.25   8538.5   9769.75  11001.0
# 1   37306.798862  2250.0  2484.00   2718.0  34909.00  67100.0
# 2    6152.511107   536.0  2483.75   4445.0   7989.00  14685.0
# 3    5878.885779   551.0  2629.50   4708.0   6786.50   8865.0
# 4    7210.977281   355.0  1736.25   4267.0   8362.25  34856.0
# 5            NaN     NaN      NaN      NaN       NaN      NaN
# 6   30710.020986   284.0  2986.00   3920.0   4957.00  95450.0
# 7    1224.590077   640.0  1215.25   2015.5   2748.25   4195.0
# 8            NaN  7317.0  7317.00   7317.0   7317.00   7317.0
# 9    7782.629942     0.0  2368.00  11755.0  15113.50  18712.0
# 10   2548.110346   132.0   371.00    610.0   2687.50   4765.0
# 11   7925.586384     0.0  1505.00   2404.0   4561.00  35324.0
# 12           NaN   211.0   211.00    211.0    211.00    211.0
# 13   1348.400658   540.0   651.50    763.0   1871.00   2979.0
# 14   2715.290040   115.0  1075.00   2035.0   2995.00   3955.0
# 15  13058.081659     0.0   378.25   2864.0   7735.00  34948.0
# 16   2517.924079   780.0  1724.25   3333.0   5062.25   6368.0
# 17  18215.303870     0.0  4318.75   6627.0  13040.50  75193.0
# 18   4253.282767     0.0  2326.00   4271.0   8831.00  14661.0
# 19   4889.643392  1114.0  2842.75   4571.5   6300.25   8029.0
#
# [20 rows x 57 columns]

# %%
sns.set(rc={"figure.figsize": (10, 8)}, font_scale=2)

def plot_pie_chart():
    colors = sns.color_palette('bright')
    plt.title('Image prediction Accuracy for p1_dog group')
    labels = ['False', 'True']
    plt.pie(best_prediction, labels=labels,
            colors=colors, autopct='%.0f%%')


plot_pie_chart()

# %% [markdown]
# # References
# * https://stackoverflow.com/questions/28384588/twitter-api-get-tweets-with-specific-id
# * https://www.shanelynn.ie/pandas-drop-delete-dataframe-rows-columns/
